# %% [markdown]
# #Introduction to the Research Environment
#
# The research environment is powered by IPython notebooks, which allow one to perform a great deal of data analysis and statistical validation. We'll demonstrate a few simple techniques here.

# %% [markdown]
# #Introduction to Google Colab
# ##Nicolas Sanchez Vargas
# Esta es la lectura 1 de Quantopian en Google Colab

# %% [markdown]
# ##Code Cells vs. Text Cells
#
# As you can see, each cell can be either code or text. To select between them, choose from the 'Cell Type' dropdown menu on the top left.

# %% [markdown]
# ##Executing a Command
#
# A code cell will be evaluated when you press play, or when you press the shortcut, shift-enter. Evaluating a cell evaluates each line of code in sequence, and prints the results of the last line below the cell.

# %%
2 + 2
# Out:
# 4

# %%
1 + 5
# Out:
# 6

# %% [markdown]
# Sometimes there is no result to be printed, as is the case with assignment.

# %%
X = 2

# %%
y =  6

# %% [markdown]
# Remember that only the result from the last line is printed.

# %%
2 + 2
3 + 3
# Out:
# 6

# %%
0 + 0
6 + 10
# Out:
# 16

# %% [markdown]
# However, you can print whichever lines you want using the `print` statement.

# %%
print (2 + 2)
3 + 3
# Out:
# 4
# 6

# %%
print (29 + 32)
15 + 0
# Out:
# 61
# 15

# %% [markdown]
# ##Knowing When a Cell is Running
#
# While a cell is running, a `[*]` will display on the left. When a cell has yet to be executed, `[ ]` will display. When it has been run, a number will display indicating the order in which it was run during the execution of the notebook `[5]`. Try on this cell and note it happening.

# %%
#Take some time to run something
c = 0
for i in range(10000000):
    c = c + i
c
# Out:
# 49999995000000

# %%
a = 0
for i in range(501):
    a = a + i
print(i)
a
# Out:
# 500
# 125250

# %% [markdown]
# El codigo anterior es la suma de los $n$ primeros numeros, en este caso $n$ = 500
# #Formula de la suma de los primeros n numeros :
# $$ 1 + 2 + 3 + \ldots + (n - 1) + n = \sum_{i=1}^n i = \frac{n(n+1)}{2}$$

# %% [markdown]
# ##Importing Libraries
#
# The vast majority of the time, you'll want to use functions from pre-built libraries. You can't import every library on Quantopian due to security issues, but you can import most of the common scientific ones. Here I import numpy and pandas, the two most common and useful libraries in quant finance. I recommend copying this import statement to every new notebook.
#
# Notice that you can rename libraries to whatever you want after importing. The `as` statement allows this. Here we use `np` and `pd` as aliases for `numpy` and `pandas`. This is a very common aliasing and will be found in most code snippets around the web. The point behind this is to allow you to type fewer characters when you are frequently accessing these libraries.

# %%
import numpy as np
import pandas as pd

# This is a plotting library for pretty pictures.
import matplotlib.pyplot as plt

# %%
import numpy as nup
import pandas as pad
import matplotlib.pyplot as matp

# %% [markdown]
# #Apartir de aqui sencillamente remplazo celdas de codigo con mis definiciones para que no hayan errores si se quiere ejecutar todas las celdas a la vez

# %% [markdown]
# ##Tab Autocomplete
#
# Pressing tab will give you a list of IPython's best guesses for what you might want to type next. This is incredibly valuable and will save you a lot of time. If there is only one possible option for what you could type next, IPython will fill that in for you. Try pressing tab very frequently, it will seldom fill in anything you don't want, as if there is ambiguity a list will be shown. This is a great way to see what functions are available in a library.
#
# Try placing your cursor after the `.` and pressing tab.

# %%
   nup.random.beta
# Out:
# <function RandomState.beta>

# %% [markdown]
# ##Getting Documentation Help
#
# Placing a question mark after a function and executing that line of code will give you the documentation IPython has for that function. It's often best to do this in a new cell, as you avoid re-executing other code and running into bugs.

# %%
nup.random.normal?

# %% [markdown]
# ##Sampling
#
# We'll sample some random data using a function from `numpy`.

# %%
# Sample 100 points with a mean of 0 and an std of 1. This is a standard normal distribution.
X = nup.random.normal(0, 1, 100)

# %%
# Sample 100 points with a mean of 0 and an std of 1. This is a standard normal distribution.
j = nup.random.normal(0.5, 1, 25)

# %% [markdown]
# ##Plotting
#
# We can use the plotting library we imported as follows.

# %%
plt.plot(X)

# %%
matp.plot(j);

# %% [markdown]
# ###Squelching Line Output
#
# You might have noticed the annoying line of the form `[<matplotlib.lines.Line2D at 0x7f72fdbc1710>]` before the plots. This is because the `.plot` function actually produces output. Sometimes we wish not to display output, we can accomplish this with the semi-colon as follows.

# %%
matp.plot(X);

# %%
matp.plot(j);

# %% [markdown]
# ###Adding Axis Labels
#
# No self-respecting quant leaves a graph without labeled axes. Here are some commands to help with that.

# %%
X = nup.random.normal(0, 1, 100)
X2 = nup.random.normal(0, 1, 100)

matp.plot(X);
matp.plot(X2);
matp.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
matp.ylabel('Returns')
matp.legend(['X', 'X2']);

# %%
P = nup.random.normal(0, 1, 100)
Q = nup.random.normal(0, 1, 100)

matp.plot(P);
matp.plot(Q);
matp.xlabel('Years') # The data we generated is unitless, but don't forget units in general.
matp.ylabel('Returns')
matp.legend(['P', 'Q']);

# %% [markdown]
# ##Generating Statistics
#
# Let's use `numpy` to take some simple statistics.

# %%
nup.mean(X)
# Out:
# 0.07263314645572778

# %%
nup.mean(P)
# Out:
# -0.04722818007418356

# %%
nup.std(X)
# Out:
# 0.9183678290944007

# %%
nup.std(P)
# Out:
# 0.9691697294217541

# %% [markdown]
# ##Getting Real Pricing Data
#
# Randomly sampled data can be great for testing ideas, but let's get some real data. We can use `get_pricing` to do that. You can use the `?` syntax as discussed above to get more information on `get_pricing`'s arguments.

# %% [markdown]
# #Debido a que ninguno de los comandos de la lectura que siguen funcionan, solo dejo el codigo con mi ejemplo

# %%
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (4.2.6)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (1.1.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pdr.get_data_yahoo('AAPL', start= datetime(2020,6,1), end=datetime(2020,8,1))

# %% [markdown]
# Our data is now a dataframe. You can see the datetime index and the colums with different pricing data.

# %%
data
# Out:
#                   High         Low  ...     Volume   Adj Close
# Date                                ...
# 2020-06-01   80.587502   79.302498  ...   80791200   80.059723
# 2020-06-02   80.860001   79.732498  ...   87642800   80.430351
# 2020-06-03   81.550003   80.574997  ...  104491200   80.873131
# 2020-06-04   81.404999   80.195000  ...   87560400   80.176636
# 2020-06-05   82.937500   80.807503  ...  137250400   82.460152
# 2020-06-08   83.400002   81.830002  ...   95654400   82.947685
# 2020-06-09   86.402496   83.002502  ...  147712400   85.567009
# 2020-06-10   88.692497   86.522499  ...  166651600   87.768440
# 2020-06-11   87.764999   83.870003  ...  201662400   83.554642
# 2020-06-12   86.949997   83.555000  ...  200146000   84.276009
# 2020-06-22     89.268394
# 2020-06-23     91.173805
# 2020-06-24     89.564407
# 2020-06-25     90.753426
# 2020-06-26     87.964951
# 2020-06-29     89.992256
# 2020-06-30     90.743469
# 2020-07-01     90.571838
# 2020-07-02     90.571838
# 2020-07-06     92.994652
# 2020-07-07     92.706093
# 2020-07-08     94.865234
# 2020-07-09     95.273193
# 2020-07-10     95.439842
# 2020-07-13     94.999557
# 2020-07-14     96.571655
# 2020-07-15     97.235809
# 2020-07-16     96.039330
# 2020-07-17     95.845299
# 2020-07-20     97.865143
# 2020-07-21     96.514442
# 2020-07-22     96.785568
# 2020-07-23     92.380234
# 2020-07-24     92.151382
# 2020-07-27     94.335396
# 2020-07-28     92.785706
# 2020-07-29     94.564247
# 2020-07-30     95.708496
# 2020-07-31    105.728088
# Name: Adj Close, dtype: float64 <class 'pandas.core.series.Series'>

# %% [markdown]
# Because there is now also date information in our data, we provide two series to `.plot`. `X.index` gives us the datetime index, and `X.values` gives us the pricing values. These are used as the X and Y coordinates to make a graph.

# %%
plt.plot(x.index, x.values)
plt.ylabel('adj Close')
plt.legend(['Apple']);

# %% [markdown]
# We can get statistics again on real data.

# %%
np.mean(x)
# Out:
# 90.5533492348411

# %%
np.std(x)
# Out:
# 5.633412774496821

# %% [markdown]
# ##Getting Returns from Prices
#
# We can use the `pct_change` function to get returns. Notice how we drop the first element after doing this, as it will be `NaN` (nothing -> something results in a NaN percent change).

# %%
R = x.pct_change()[1:]

# %%
print(R)
# Out:
# Date
# 2020-06-02    0.004629
# 2020-06-03    0.005505
# 2020-06-04   -0.008612
# 2020-06-05    0.028481
# 2020-06-08    0.005912
# 2020-06-09    0.031578
# 2020-06-10    0.025728
# 2020-06-11   -0.048010
# 2020-06-12    0.008633
# 2020-06-15    0.012367
# 2020-06-16    0.026502
# 2020-06-17   -0.001392
# 2020-06-18    0.000398
# 2020-06-19   -0.005715
# 2020-06-22    0.026164
# 2020-06-23    0.021345
# 2020-06-24   -0.017652
# 2020-06-25    0.013276
# 2020-06-26   -0.030726
# 2020-06-29    0.023047
# 2020-06-30    0.008348
# 2020-07-01   -0.001891
# 2020-07-02    0.000000
# 2020-07-06    0.026750
# 2020-07-07   -0.003103
# 2020-07-08    0.023290
# 2020-07-09    0.004300
# 2020-07-10    0.001749
# 2020-07-13   -0.004613
# 2020-07-14    0.016548
# 2020-07-15    0.006877
# 2020-07-16   -0.012305
# 2020-07-17   -0.002020
# 2020-07-20    0.021074
# 2020-07-21   -0.013802
# 2020-07-22    0.002809
# 2020-07-23   -0.045516
# 2020-07-24   -0.002477
# 2020-07-27    0.023700
# 2020-07-28   -0.016427
# 2020-07-29    0.019168
# 2020-07-30    0.012100
# 2020-07-31    0.104689
# Name: Adj Close, dtype: float64

# %% [markdown]
# We can plot the returns distribution as a histogram.

# %%
plt.hist(R, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['AAPL Returns']);

# %% [markdown]
# Get statistics again.

# %%
np.mean(R)
# Out:
# 0.0067606265327529

# %%
np.std(R)
# Out:
# 0.023587747572796552

# %% [markdown]
# Now let's go backwards and generate data out of a normal distribution using the statistics we estimated from Microsoft's returns. We'll see that we have good reason to suspect Microsoft's returns may not be normal, as the resulting normal distribution looks far different.

# %%
plt.hist(np.random.normal(np.mean(R), np.std(R), 10000), bins=40)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['Normally Distributed Returns']);

# %% [markdown]
# ##Generating a Moving Average
#
# `pandas` has some nice tools to allow us to generate rolling statistics. Here's an example. Notice how there's no moving average for the first 60 days, as we don't have 60 days of data on which to generate the statistic.

# %%
import pandas as pd
MAVG = x.rolling(60).mean()
plt.plot(x.index, x.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Adj Close')
plt.legend(['AAPL', '60-day MAVG']);

# %% [markdown]
# This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company. In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.
