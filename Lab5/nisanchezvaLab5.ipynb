# %% [markdown]
# #Para 2 Años, con un presupuesto inicial de 100.000.000 y para la siguientes acciones : Facebook, Amazon, Google, Sony y Apple.
# ##Se eligieron estas acciónes debido al incremento de su precio en los ultimos años, obtuve esta información a partir de busquedas en yahoo finance de distintas empresas.

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):

        self.SetCash(100000000)
        self.SetStartDate(2019, 4, 20)
        self.SetEndDate(2021, 4, 20)

        
        self.fb = self.AddEquity("FB", Resolution.Minute)
        self.fb.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.amzn = self.AddEquity("AMZN", Resolution.Minute)
        self.amzn.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.goog = self.AddEquity("GOOG", Resolution.Minute)
        self.goog.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.sony = self.AddEquity("SONY", Resolution.Minute)
        self.sony.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.aapl = self.AddEquity("AAPL", Resolution.Minute)
        self.aapl.SetDataNormalizationMode(DataNormalizationMode.Raw)

        

    def OnData(self, data):
    
        
        if not self.Portfolio.Invested:
            self.SetHoldings("FB", 0.2)
            self.Debug(str(self.Portfolio["FB"].AveragePrice))
            self.SetHoldings("AMZN", 0.2)
            self.Debug(str(self.Portfolio["AMZN"].AveragePrice))
            self.SetHoldings("GOOG", 0.2)
            self.Debug(str(self.Portfolio["GOOG"].AveragePrice))
            self.SetHoldings("SONY", 0.2)
            self.Debug(str(self.Portfolio["SONY"].AveragePrice))
            self.SetHoldings("AAPL", 0.2)
            self.Debug(str(self.Portfolio["AAPL"].AveragePrice))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Para 6 meses, con un presupuesto inicial de 1000 y para la siguientes acciones : Sundial Growers Inc., Green Globe International, Inc., KYN Capital Group, Inc., 22nd Century Group, Inc. y Pennsylvania Real Estate Investment Trust.
# ##Se eligieron estas acciónes debido al incremento de su precio en los ultimos años, obtuve esta información a partir de busquedas en distintas "watchlists" con acciones de bajo precio en yahoo finance, el objetivo del presopuesto bajo y de que el precio de las acciones tambien sea bajo es que represente un escenario que podria tener una persona "normal" que empieza a invertir en la bolsa.

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):

        self.SetCash(1000)
        self.SetStartDate(2020, 10, 20)
        self.SetEndDate(2021, 4, 20)

        
        self.SNDL = self.AddEquity("SNDL", Resolution.Minute)
        self.SNDL.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.GGII = self.AddEquity("GGII", Resolution.Minute)
        self.GGII.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.KYNC = self.AddEquity("KYNC", Resolution.Minute)
        self.KYNC.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.XXII = self.AddEquity("XXII", Resolution.Minute)
        self.XXII.SetDataNormalizationMode(DataNormalizationMode.Raw)
        self.PEI = self.AddEquity("PEI", Resolution.Minute)
        self.PEI.SetDataNormalizationMode(DataNormalizationMode.Raw)

        

    def OnData(self, data):
    
        
        if not self.Portfolio.Invested:
            self.SetHoldings("SNDL", 0.20)
            self.Debug(str(self.Portfolio["SNDL"].AveragePrice))
            self.SetHoldings("GGII", 0.20)
            self.Debug(str(self.Portfolio["GGII"].AveragePrice))
            self.SetHoldings("KYNC", 0.20)
            self.Debug(str(self.Portfolio["KYNC"].AveragePrice))
            self.SetHoldings("XXII", 0.20)
            self.Debug(str(self.Portfolio["XXII"].AveragePrice))
            self.SetHoldings("PEI", 0.20)
            self.Debug(str(self.Portfolio["PEI"].AveragePrice))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
