# %%
import numpy as np
rate_return = 102.0/100 - 1
print(rate_return)
# Out:
# 0.020000000000000018

# %%
pip install quandl

# %% [markdown]
# ##Quandl me pide que confirme mi correo para poder usar el servicio pero por mas que intento con distintos correos y cuentas en quandl, nunca llega y por lo tanto no lo puedo confirmar

# %%
import numpy as np
import quandl
quandl.ApiConfig.api_key = 'tAyfv1zpWnyhmDsp91yv'
#get quandl data
aapl_table = quandl.get('WIKI/AAPL')
aapl = aapl_table.loc['2017-3',['Open','Close']]
#take log return
aapl['log_price'] = np.log(aapl.Close)
aapl['log_return'] = aapl.log_price.diff()
print(aapl)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-4-766f89da8863> in <module>()
#       3 quandl.ApiConfig.api_key = 'tAyfv1zpWnyhmDsp91yv'
#       4 #get quandl data
# ----> 5 aapl_table = quandl.get('WIKI/AAPL')
#       6 aapl = aapl_table.loc['2017-3',['Open','Close']]
#       7 #take log return
#
# /usr/local/lib/python3.7/dist-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /usr/local/lib/python3.7/dist-packages/quandl/model/dataset.py in data(self, **options)
# ...

# %%
goog_table = quandl.get('WIKI/GOOG')
goog = goog_table.loc['2018-1',['Open','Close']]

goog['log_price'] = np.log(goog.Close)
goog['log_return'] = goog.log_price.diff()
print(goog)

# %%
month_return = aapl.log_return.sum()
print(month_return)
# Out:
# 0.0273081001636184

# %%
month_return2 = goog.log_return.sum()
print(month_return2)

# %%
print(np.mean(aapl.log_price))
# Out:
# 4.94597446550658

# %%
print(np.mean(goog.log_price))

# %%
print(np.var(aapl.log_price))
# Out:
# 0.00014203280448152512

# %%
print(np.var(goog.log_price))
