# %%
pip install quandl

# %%
import quandl
import numpy as np
import pandas as pd

# %% [markdown]
# ##Quandl me pide que confirme mi correo para poder usar el servicio pero por mas que intento con distintos correos y cuentas en quandl, nunca llega y por lo tanto no lo puedo confirmar

# %%
quandl.ApiConfig.api_key = 'Sfb7Bj86ySa1eztH74f-'
aapl_table = quandl.get('WIKI/AAPL')
# Out:
# ---------------------------------------------------------------------------
# ForbiddenError                            Traceback (most recent call last)
# <ipython-input-27-23b0e78fb8b1> in <module>()
#       1 quandl.ApiConfig.api_key = 'Sfb7Bj86ySa1eztH74f-'
# ----> 2 aapl_table = quandl.get('WIKI/AAPL')
#
# /usr/local/lib/python3.7/dist-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /usr/local/lib/python3.7/dist-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
# ...

# %%
quandl.ApiConfig.api_key = 'FEy2EwhUxMvqkb1D47ni'
goog_table = quandl.get('WIKI/GOOG')

# %%
aapl = aapl_table['Adj. Close']['2017']

# %%
goog = goog_table['Adj. Close']['2018']

# %%
print(aapl)
# Out:
# Date
# 2017-01-03    114.715378
# 2017-01-04    114.586983
# 2017-01-05    115.169696
# 2017-01-06    116.453639
# 2017-01-09    117.520300
# 2017-01-10    117.638817
# 2017-01-11    118.270913
# 2017-01-12    117.777088
# 2017-01-13    117.569682
# 2017-01-17    118.517825
# 2017-01-18    118.507948
# 2017-01-19    118.300542
# 2017-01-20    118.517825
# 2017-01-23    118.596837
# 2017-01-24    118.488195
# 2017-01-25    120.374604
# 2017-01-26    120.433863
# 2017-01-27    120.443739
# 2017-01-30    120.127692
# 2017-01-31    119.851150
# 2017-02-01    127.159749
# 2017-02-02    126.942467
# 2017-02-03    127.485673
# 2017-02-06    128.680728
# 2017-02-07    129.905412
# 2017-02-08    130.409113
# 2017-02-09    131.347379
# 2017-02-10    131.049809
# 2017-02-13    132.210332
# 2017-02-14    133.926319
#                  ...
# 2017-11-16    171.100000
# 2017-11-17    170.150000
# 2017-11-20    169.980000
# 2017-11-21    173.140000
# 2017-11-22    174.960000
# ...

# %%
print(goog)

# %%
print(aapl['2017-3'])
# Out:
# Date
# 2017-03-01    138.657681
# 2017-03-02    137.834404
# 2017-03-03    138.647762
# 2017-03-06    138.211326
# 2017-03-07    138.389868
# 2017-03-08    137.874080
# 2017-03-09    137.556672
# 2017-03-10    138.012946
# 2017-03-13    138.072460
# 2017-03-14    137.864161
# 2017-03-15    139.322254
# 2017-03-16    139.550391
# 2017-03-17    138.856061
# 2017-03-20    140.314154
# 2017-03-21    138.707276
# 2017-03-22    140.274478
# 2017-03-23    139.778528
# 2017-03-24    139.500796
# 2017-03-27    139.738852
# 2017-03-28    142.635200
# 2017-03-29    142.952608
# 2017-03-30    142.764147
# 2017-03-31    142.496334
# Name: Adj. Close, dtype: float64

# %%
print(goog['2018-2'])

# %%
aapl['2017-2':'2017-4']
# Out:
# Date
# 2017-02-01    127.159749
# 2017-02-02    126.942467
# 2017-02-03    127.485673
# 2017-02-06    128.680728
# 2017-02-07    129.905412
# 2017-02-08    130.409113
# 2017-02-09    131.347379
# 2017-02-10    131.049809
# 2017-02-13    132.210332
# 2017-02-14    133.926319
# 2017-02-15    134.412350
# 2017-02-16    134.248686
# 2017-02-17    134.620649
# 2017-02-21    135.592711
# 2017-02-22    135.999390
# 2017-02-23    135.424088
# 2017-02-24    135.553035
# 2017-02-27    135.820848
# 2017-02-28    135.880362
# 2017-03-01    138.657681
# 2017-03-02    137.834404
# 2017-03-03    138.647762
# 2017-03-06    138.211326
# 2017-03-07    138.389868
# 2017-03-08    137.874080
# 2017-03-09    137.556672
# 2017-03-10    138.012946
# 2017-03-13    138.072460
# 2017-03-14    137.864161
# 2017-03-15    139.322254
#                  ...
# 2017-03-17    138.856061
# 2017-03-20    140.314154
# 2017-03-21    138.707276
# 2017-03-22    140.274478
# 2017-03-23    139.778528
# ...

# %%
goog['2018-4':'2018-7']

# %%
print(aapl.head(5))
print(aapl.tail(10))
# Out:
# Date
# 2017-01-03    114.715378
# 2017-01-04    114.586983
# 2017-01-05    115.169696
# 2017-01-06    116.453639
# 2017-01-09    117.520300
# Name: Adj. Close, dtype: float64
# Date
# 2017-12-15    173.87
# 2017-12-18    176.42
# 2017-12-19    174.54
# 2017-12-20    174.35
# 2017-12-21    175.01
# 2017-12-22    175.01
# 2017-12-26    170.57
# 2017-12-27    170.60
# 2017-12-28    171.08
# 2017-12-29    169.23
# Name: Adj. Close, dtype: float64

# %%
print(goog.head(3))
print(goog.tail(5))

# %%
by_month = aapl.resample('M').mean()
print(by_month)
# Out:
# Date
# 2017-01-31    118.093136
# 2017-02-28    132.456268
# 2017-03-31    139.478802
# 2017-04-30    141.728436
# 2017-05-31    151.386305
# 2017-06-30    147.233064
# 2017-07-31    147.706190
# 2017-08-31    158.856375
# 2017-09-30    157.606500
# 2017-10-31    157.811627
# 2017-11-30    172.214500
# 2017-12-31    171.893100
# Freq: M, Name: Adj. Close, dtype: float64

# %%
by_month2 = goog.resample('M').mean()
print(by_month2)

# %%
by_week = aapl.resample('W').mean()
print(by_week.head())
# Out:
# Date
# 2017-01-08    115.231424
# 2017-01-15    117.755360
# 2017-01-22    118.461035
# 2017-01-29    119.667448
# 2017-02-05    124.313346
# Freq: W-SUN, Name: Adj. Close, dtype: float64

# %%
by_week2 = goog.resample('W').mean()
print(by_week2.head())

# %%
aapl.resample('M').max()
# Out:
# Date
# 2017-01-31    120.443739
# 2017-02-28    135.999390
# 2017-03-31    142.952608
# 2017-04-30    143.597342
# 2017-05-31    155.469192
# 2017-06-30    154.821818
# 2017-07-31    152.839860
# 2017-08-31    164.000000
# 2017-09-30    164.050000
# 2017-10-31    169.040000
# 2017-11-30    175.880000
# 2017-12-31    176.420000
# Freq: M, Name: Adj. Close, dtype: float64

# %%
goog.resample('M').max()

# %%
three_day = aapl.resample('3D').mean()
two_week = aapl.resample('2W').mean()
two_month = aapl.resample('2M').mean()

# %%
three_day2 = goog.resample('3D').mean()
two_week2 = goog.resample('2W').mean()
two_month2 = goog.resample('2M').mean()

# %%
std = aapl.resample('W').std()
max = aapl.resample('W').max()
min = aapl.resample('W').min()

# %%
std2 = goog.resample('W').std()
max2 = goog.resample('W').max()
min2 = goog.resample('W').min()

# %%
monthly_return = aapl.resample('M').agg(lambda x: x[-1]/x[1] - 1)
print(monthly_return)
# Out:
# Date
# 2017-01-31    0.045940
# 2017-02-28    0.070409
# 2017-03-31    0.033823
# 2017-04-30   -0.007736
# 2017-05-31    0.039829
# 2017-06-30   -0.073528
# 2017-07-31    0.033035
# 2017-08-31    0.047890
# 2017-09-30   -0.049112
# 2017-10-31    0.094252
# 2017-11-30    0.022247
# 2017-12-31   -0.003357
# Freq: M, Name: Adj. Close, dtype: float64

# %%
monthly_return2 = goog.resample('M').agg(lambda x: x[-1]/x[1] - 1)
print(monthly_return2)

# %%
last_day = aapl.resample('M').agg(lambda x: x[-1])
print(last_day)
# Out:
# Date
# 2017-01-31    119.851150
# 2017-02-28    135.880362
# 2017-03-31    142.496334
# 2017-04-30    142.486415
# 2017-05-31    152.142689
# 2017-06-30    143.438008
# 2017-07-31    148.248489
# 2017-08-31    164.000000
# 2017-09-30    154.120000
# 2017-10-31    169.040000
# 2017-11-30    171.850000
# 2017-12-31    169.230000
# Freq: M, Name: Adj. Close, dtype: float64

# %%
last_day2 = goog.resample('M').agg(lambda x: x[-1])
print(last_day2)

# %%
by_week = aapl.resample('W').mean()

# %%
by_week2 = goog.resample('W').mean()

# %%
twomon = aapl.resample('2M').std()
twomon
# Out:
# Date
# 2017-01-31    1.781512
# 2017-03-31    4.323834
# 2017-05-31    5.454495
# 2017-07-31    3.865333
# 2017-09-30    3.634223
# 2017-11-30    8.011704
# 2018-01-31    2.291229
# Freq: 2M, Name: Adj. Close, dtype: float64

# %%
twomon2 = goog.resample('2M').std()
twomon2

# %%
last_day = aapl.resample('M').agg(lambda x: x[-1])
last_day
# Out:
# Date
# 2017-01-31    119.851150
# 2017-02-28    135.880362
# 2017-03-31    142.496334
# 2017-04-30    142.486415
# 2017-05-31    152.142689
# 2017-06-30    143.438008
# 2017-07-31    148.248489
# 2017-08-31    164.000000
# 2017-09-30    154.120000
# 2017-10-31    169.040000
# 2017-11-30    171.850000
# 2017-12-31    169.230000
# Freq: M, Name: Adj. Close, dtype: float64

# %%
last_day2 = goog.resample('M').agg(lambda x: x[-1])
last_day2

# %%
monthly_return = aapl.resample('M').agg(lambda x: x[-1]/x[1] - 1)
monthly_return
# Out:
# Date
# 2017-01-31    0.045940
# 2017-02-28    0.070409
# 2017-03-31    0.033823
# 2017-04-30   -0.007736
# 2017-05-31    0.039829
# 2017-06-30   -0.073528
# 2017-07-31    0.033035
# 2017-08-31    0.047890
# 2017-09-30   -0.049112
# 2017-10-31    0.094252
# 2017-11-30    0.022247
# 2017-12-31   -0.003357
# Freq: M, Name: Adj. Close, dtype: float64

# %%
monthly_return2 = goog.resample('M').agg(lambda x: x[-1]/x[1] - 1)
monthly_return2

# %%
print(monthly_return.mean())
print(monthly_return.std())
print(monthly_return.max())
# Out:
# 0.02114094011940022
# 0.04775652864223314
# 0.09425168306576914

# %%
print(monthly_return2.mean())
print(monthly_return2.std())
print(monthly_return2.max())

# %%
print(last_day.diff())
print(last_day.pct_change())
# Out:
# Date
# 2017-01-31          NaN
# 2017-02-28    16.029211
# 2017-03-31     6.615972
# 2017-04-30    -0.009919
# 2017-05-31     9.656274
# 2017-06-30    -8.704681
# 2017-07-31     4.810482
# 2017-08-31    15.751511
# 2017-09-30    -9.880000
# 2017-10-31    14.920000
# 2017-11-30     2.810000
# 2017-12-31    -2.620000
# Freq: M, Name: Adj. Close, dtype: float64
# Date
# 2017-01-31         NaN
# 2017-02-28    0.133743
# 2017-03-31    0.048690
# 2017-04-30   -0.000070
# 2017-05-31    0.067770
# 2017-06-30   -0.057214
# 2017-07-31    0.033537
# 2017-08-31    0.106251
# 2017-09-30   -0.060244
# 2017-10-31    0.096808
# 2017-11-30    0.016623
# 2017-12-31   -0.015246
# Freq: M, Name: Adj. Close, dtype: float64

# %%
print(last_day2.diff())
print(last_day2.pct_change())

# %%
print(aapl.describe())
# Out:
# count    249.000000
# mean     149.815713
# std       15.065681
# min      114.586983
# 25%      140.651400
# 50%      151.890000
# 75%      159.780000
# max      176.420000
# Name: Adj. Close, dtype: float64

# %%
print(goog.describe())

# %%
daily_return = last_day.pct_change()
print(daily_return.fillna(0))
# Out:
# Date
# 2017-01-31    0.000000
# 2017-02-28    0.133743
# 2017-03-31    0.048690
# 2017-04-30   -0.000070
# 2017-05-31    0.067770
# 2017-06-30   -0.057214
# 2017-07-31    0.033537
# 2017-08-31    0.106251
# 2017-09-30   -0.060244
# 2017-10-31    0.096808
# 2017-11-30    0.016623
# 2017-12-31   -0.015246
# Freq: M, Name: Adj. Close, dtype: float64

# %%
daily_return2 = last_day2.pct_change()
print(daily_return2.fillna(0))

# %%
daily_return = last_day.pct_change()
print(daily_return.fillna(method = 'bfill'))
# Out:
# Date
# 2017-01-31    0.133743
# 2017-02-28    0.133743
# 2017-03-31    0.048690
# 2017-04-30   -0.000070
# 2017-05-31    0.067770
# 2017-06-30   -0.057214
# 2017-07-31    0.033537
# 2017-08-31    0.106251
# 2017-09-30   -0.060244
# 2017-10-31    0.096808
# 2017-11-30    0.016623
# 2017-12-31   -0.015246
# Freq: M, Name: Adj. Close, dtype: float64

# %%
daily_return2 = last_day2.pct_change()
print(daily_return2.fillna(method = 'bfill'))

# %%
daily_return = last_day.pct_change()
daily_return.dropna()
# Out:
# Date
# 2017-02-28    0.133743
# 2017-03-31    0.048690
# 2017-04-30   -0.000070
# 2017-05-31    0.067770
# 2017-06-30   -0.057214
# 2017-07-31    0.033537
# 2017-08-31    0.106251
# 2017-09-30   -0.060244
# 2017-10-31    0.096808
# 2017-11-30    0.016623
# 2017-12-31   -0.015246
# Freq: M, Name: Adj. Close, dtype: float64

# %%
daily_return2 = last_day.pct_change()
daily_return2.dropna()

# %%
# aapl.resample('M').agg(lambda x: max(x) - min(x))

# %%
dict = {'AAPL': [143.5, 144.09, 142.73, 144.18, 143.77],'GOOG':[898.7, 911.71, 906.69, 918.59, 926.99],
        'IBM':[155.58, 153.67, 152.36, 152.94, 153.49]}
data_index = pd.date_range('2017-07-03',periods = 5, freq = 'D')
df = pd.DataFrame(dict, index = data_index)
print(df)
# Out:
#               AAPL    GOOG     IBM
# 2017-07-03  143.50  898.70  155.58
# 2017-07-04  144.09  911.71  153.67
# 2017-07-05  142.73  906.69  152.36
# 2017-07-06  144.18  918.59  152.94
# 2017-07-07  143.77  926.99  153.49

# %%
dict2 = {'TWTR': [155.58, 153.67, 152.36, 152.94, 153.49],'GOOG':[898.7, 911.71, 906.69, 918.59, 926.99],
        'FB':[241.78, 242.7, 246.73, 254.19, 255.4]}
data_index2 = pd.date_range('2018-01-01',periods = 5, freq = 'D')
df2 = pd.DataFrame(dict2, index = data_index2)
print(df2)
# Out:
#               TWTR    GOOG      FB
# 2018-01-01  155.58  898.70  241.78
# 2018-01-02  153.67  911.71  242.70
# 2018-01-03  152.36  906.69  246.73
# 2018-01-04  152.94  918.59  254.19
# 2018-01-05  153.49  926.99  255.40

# %%
s1 = pd.Series([143.5, 144.09, 142.73, 144.18, 143.77], name = 'AAPL')
s2 = pd.Series([898.7, 911.71, 906.69, 918.59, 926.99], name = 'GOOG')
data_frame = pd.concat([s1,s2], axis = 1)
print(data_frame)
# Out:
#      AAPL    GOOG
# 0  143.50  898.70
# 1  144.09  911.71
# 2  142.73  906.69
# 3  144.18  918.59
# 4  143.77  926.99

# %%
s12 = pd.Series([155.58, 153.67, 152.36, 152.94, 153.49], name = 'TWTR')
s22 = pd.Series([898.7, 911.71, 906.69, 918.59, 926.99], name = 'GOOG')
data_frame2 = pd.concat([s12,s22], axis = 1)
print(data_frame2)
# Out:
#      TWTR    GOOG
# 0  155.58  898.70
# 1  153.67  911.71
# 2  152.36  906.69
# 3  152.94  918.59
# 4  153.49  926.99

# %%
print(df.columns)
print(df.AAPL)
print(df['GOOG'])
# Out:
# Index(['AAPL', 'GOOG', 'IBM'], dtype='object')
# 2017-07-03    143.50
# 2017-07-04    144.09
# 2017-07-05    142.73
# 2017-07-06    144.18
# 2017-07-07    143.77
# Freq: D, Name: AAPL, dtype: float64
# 2017-07-03    898.70
# 2017-07-04    911.71
# 2017-07-05    906.69
# 2017-07-06    918.59
# 2017-07-07    926.99
# Freq: D, Name: GOOG, dtype: float64

# %%
print(df2.columns)
print(df2.TWTR)
print(df2['TWTR'])
# Out:
# Index(['TWTR', 'GOOG', 'FB'], dtype='object')
# 2018-01-01    155.58
# 2018-01-02    153.67
# 2018-01-03    152.36
# 2018-01-04    152.94
# 2018-01-05    153.49
# Freq: D, Name: TWTR, dtype: float64
# 2018-01-01    155.58
# 2018-01-02    153.67
# 2018-01-03    152.36
# 2018-01-04    152.94
# 2018-01-05    153.49
# Freq: D, Name: TWTR, dtype: float64

# %%
df = aapl_table
print(df.Close.tail(5))
print(df['Adj. Volume'].tail(5))
# Out:
# Date
# 2018-03-21    171.270
# 2018-03-22    168.845
# 2018-03-23    164.940
# 2018-03-26    172.770
# 2018-03-27    168.340
# Name: Close, dtype: float64
# Date
# 2018-03-21    35247358.0
# 2018-03-22    41051076.0
# 2018-03-23    40248954.0
# 2018-03-26    36272617.0
# 2018-03-27    38962839.0
# Name: Adj. Volume, dtype: float64

# %%
df2 = goog_table
print(df2.Close.tail(3))
print(df2['Adj. Volume'].tail(3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-572bb4a9518b> in <module>()
# ----> 1 df2 = goog_table
#       2 print(df2.Close.tail(3))
#       3 print(df2['Adj. Volume'].tail(3))
#
# NameError: name 'goog_table' is not defined

# %%
aapl_2016 = df['2016']
aapl_month = aapl_2016.resample('M').agg(lambda x: x[-1])
print(aapl_month)
# Out:
#               Open      High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34  64416504.0          0.0
# 2016-02-29   96.86   98.2300   96.65   96.69  35216277.0          0.0
# 2016-03-31  109.72  109.9000  108.88  108.99  25888449.0          0.0
# 2016-04-30   93.99   94.7200   92.51   93.74  68531478.0          0.0
# 2016-05-31   99.60  100.4000   98.82   99.86  42307212.0          0.0
# 2016-06-30   94.44   95.7700   94.30   95.60  35836356.0          0.0
# 2016-07-31  104.19  104.5500  103.68  104.21  27733688.0          0.0
# 2016-08-31  105.66  106.5699  105.64  106.10  29662406.0          0.0
# 2016-09-30  112.46  113.3700  111.80  113.05  36379106.0          0.0
# 2016-10-31  113.65  114.2300  113.20  113.54  26419398.0          0.0
# 2016-11-30  111.56  112.2000  110.27  110.52  36162258.0          0.0
# 2016-12-31  116.65  117.2000  115.43  115.82  30586265.0          0.0
#
# ...

# %%
goog_2018 = df2['2018']
goog_month = goog_2018.resample('M').agg(lambda x: x[-1])
print(goog_month)

# %%
aapl_bar = aapl_month[['Open', 'High', 'Low', 'Close']]
print(aapl_bar)
# Out:
#               Open      High     Low   Close
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34
# 2016-02-29   96.86   98.2300   96.65   96.69
# 2016-03-31  109.72  109.9000  108.88  108.99
# 2016-04-30   93.99   94.7200   92.51   93.74
# 2016-05-31   99.60  100.4000   98.82   99.86
# 2016-06-30   94.44   95.7700   94.30   95.60
# 2016-07-31  104.19  104.5500  103.68  104.21
# 2016-08-31  105.66  106.5699  105.64  106.10
# 2016-09-30  112.46  113.3700  111.80  113.05
# 2016-10-31  113.65  114.2300  113.20  113.54
# 2016-11-30  111.56  112.2000  110.27  110.52
# 2016-12-31  116.65  117.2000  115.43  115.82

# %%
goog_bar = goog_month[['Open', 'High', 'Low', 'Close']]
print(goog_bar)

# %%
print(aapl_month.loc['2016-03':'2016-06',['Open', 'High', 'Low', 'Close']])
# Out:
#               Open    High     Low   Close
# Date
# 2016-03-31  109.72  109.90  108.88  108.99
# 2016-04-30   93.99   94.72   92.51   93.74
# 2016-05-31   99.60  100.40   98.82   99.86
# 2016-06-30   94.44   95.77   94.30   95.60

# %%
print(goog_month.loc['2018-01':'2018-06',['Open', 'High', 'Low', 'Close']])

# %%
above = aapl_bar[aapl_bar.Close > np.mean(aapl_bar.Close)]
print(above)
# Out:
#               Open      High     Low   Close
# Date
# 2016-03-31  109.72  109.9000  108.88  108.99
# 2016-08-31  105.66  106.5699  105.64  106.10
# 2016-09-30  112.46  113.3700  111.80  113.05
# 2016-10-31  113.65  114.2300  113.20  113.54
# 2016-11-30  111.56  112.2000  110.27  110.52
# 2016-12-31  116.65  117.2000  115.43  115.82

# %%
above2 = goog_bar[goog_bar.Close > np.mean(goog_bar.Close)]
print(above2)

# %%
aapl_bar['rate_return'] = aapl_bar.Close.pct_change()
print(aapl_bar)
# Out:
#               Open      High     Low   Close  rate_return
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34          NaN
# 2016-02-29   96.86   98.2300   96.65   96.69    -0.006678
# 2016-03-31  109.72  109.9000  108.88  108.99     0.127211
# 2016-04-30   93.99   94.7200   92.51   93.74    -0.139921
# 2016-05-31   99.60  100.4000   98.82   99.86     0.065287
# 2016-06-30   94.44   95.7700   94.30   95.60    -0.042660
# 2016-07-31  104.19  104.5500  103.68  104.21     0.090063
# 2016-08-31  105.66  106.5699  105.64  106.10     0.018136
# 2016-09-30  112.46  113.3700  111.80  113.05     0.065504
# 2016-10-31  113.65  114.2300  113.20  113.54     0.004334
# 2016-11-30  111.56  112.2000  110.27  110.52    -0.026599
# 2016-12-31  116.65  117.2000  115.43  115.82     0.047955
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
goog_bar['rate_return'] = goog_bar.Close.pct_change()
print(goog_bar)

# %%
missing = aapl_bar.isnull()
print(missing)
print('\n------------------ separate line -----------------\n')
print(missing.describe())
# Out:
#              Open   High    Low  Close  rate_return
# Date
# 2016-01-31  False  False  False  False         True
# 2016-02-29  False  False  False  False        False
# 2016-03-31  False  False  False  False        False
# 2016-04-30  False  False  False  False        False
# 2016-05-31  False  False  False  False        False
# 2016-06-30  False  False  False  False        False
# 2016-07-31  False  False  False  False        False
# 2016-08-31  False  False  False  False        False
# 2016-09-30  False  False  False  False        False
# 2016-10-31  False  False  False  False        False
# 2016-11-30  False  False  False  False        False
# 2016-12-31  False  False  False  False        False
#
# ------------------ separate line -----------------
#
#          Open   High    Low  Close rate_return
# count      12     12     12     12          12
# unique      1      1      1      1           2
# top     False  False  False  False       False
# ...

# %%
missing2 = goog_bar.isnull()
print(missing2)
print('\n------------------ separate line -----------------\n')
print(missing2.describe())

# %%
print(missing[missing.rate_return == True])
# Out:
#              Open   High    Low  Close  rate_return
# Date
# 2016-01-31  False  False  False  False         True

# %%
print(missing2[missing2.rate_return == True])

# %%
drop = aapl_bar.dropna()
print(drop)
print('\n---------------------- separate line--------------------\n')
fill = aapl_bar.fillna(0)
print(fill)
# Out:
#               Open      High     Low   Close  rate_return
# Date
# 2016-02-29   96.86   98.2300   96.65   96.69    -0.006678
# 2016-03-31  109.72  109.9000  108.88  108.99     0.127211
# 2016-04-30   93.99   94.7200   92.51   93.74    -0.139921
# 2016-05-31   99.60  100.4000   98.82   99.86     0.065287
# 2016-06-30   94.44   95.7700   94.30   95.60    -0.042660
# 2016-07-31  104.19  104.5500  103.68  104.21     0.090063
# 2016-08-31  105.66  106.5699  105.64  106.10     0.018136
# 2016-09-30  112.46  113.3700  111.80  113.05     0.065504
# 2016-10-31  113.65  114.2300  113.20  113.54     0.004334
# 2016-11-30  111.56  112.2000  110.27  110.52    -0.026599
# 2016-12-31  116.65  117.2000  115.43  115.82     0.047955
#
# ---------------------- separate line--------------------
#
#               Open      High     Low   Close  rate_return
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34     0.000000
# 2016-02-29   96.86   98.2300   96.65   96.69    -0.006678
# ...

# %%
drop2 = goog_bar.dropna()
print(drop2)
print('\n---------------------- separate line--------------------\n')
fill2 = goog_bar.fillna(0)
print(fill2)

# %%
s1 = pd.Series([143.5, 144.09, 142.73, 144.18, 143.77], name = 'AAPL')
s2 = pd.Series([898.7, 911.71, 906.69, 918.59, 926.99], name = 'GOOG')
data_frame = pd.concat([s1,s2], axis = 1)
print(data_frame)
# Out:
#      AAPL    GOOG
# 0  143.50  898.70
# 1  144.09  911.71
# 2  142.73  906.69
# 3  144.18  918.59
# 4  143.77  926.99

# %%
s12 = pd.Series([155.58, 153.67, 152.36, 152.94, 153.49], name = 'TWTR')
s22 = pd.Series([898.7, 911.71, 906.69, 918.59, 926.99], name = 'GOOG')
data_frame2 = pd.concat([s12,s22], axis = 1)
print(data_frame2)

# %%
log_price = np.log(aapl_bar.Close)
log_price.name = 'log_price'
print(log_price)
print('\n---------------------- separate line--------------------\n')
concat = pd.concat([aapl_bar, log_price], axis = 1)
print(concat)
# Out:
# Date
# 2016-01-31    4.578210
# 2016-02-29    4.571510
# 2016-03-31    4.691256
# 2016-04-30    4.540525
# 2016-05-31    4.603769
# 2016-06-30    4.560173
# 2016-07-31    4.646408
# 2016-08-31    4.664382
# 2016-09-30    4.727830
# 2016-10-31    4.732155
# 2016-11-30    4.705197
# 2016-12-31    4.752037
# Freq: M, Name: log_price, dtype: float64
#
# ---------------------- separate line--------------------
#
#               Open      High     Low   Close  rate_return  log_price
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34          NaN   4.578210
# 2016-02-29   96.86   98.2300   96.65   96.69    -0.006678   4.571510
# 2016-03-31  109.72  109.9000  108.88  108.99     0.127211   4.691256
# 2016-04-30   93.99   94.7200   92.51   93.74    -0.139921   4.540525
# 2016-05-31   99.60  100.4000   98.82   99.86     0.065287   4.603769
# 2016-06-30   94.44   95.7700   94.30   95.60    -0.042660   4.560173
# 2016-07-31  104.19  104.5500  103.68  104.21     0.090063   4.646408
# ...

# %%
log_price2 = np.log(goog_bar.Close)
log_price2.name = 'log_price'
print(log_price2)
print('\n---------------------- separate line--------------------\n')
concat2 = pd.concat([goog_bar, log_price2], axis = 1)
print(concat2)

# %%
df_volume = aapl_table.loc['2016-10':'2017-04',['Volume', 'Split Ratio']].resample('M').agg(lambda x: x[-1])
print(df_volume)
print('\n---------------------- separate line--------------------\n')
df_2017 = aapl_table.loc['2016-10':'2017-04',['Open', 'High', 'Low', 'Close']].resample('M').agg(lambda x: x[-1])
print(df_2017)
# Out:
#                 Volume  Split Ratio
# Date
# 2016-10-31  26419398.0          1.0
# 2016-11-30  36162258.0          1.0
# 2016-12-31  30586265.0          1.0
# 2017-01-31  49200993.0          1.0
# 2017-02-28  23482860.0          1.0
# 2017-03-31  19661651.0          1.0
# 2017-04-30  20247187.0          1.0
#
# ---------------------- separate line--------------------
#
#               Open     High     Low   Close
# Date
# 2016-10-31  113.65  114.230  113.20  113.54
# 2016-11-30  111.56  112.200  110.27  110.52
# 2016-12-31  116.65  117.200  115.43  115.82
# 2017-01-31  121.15  121.390  120.62  121.35
# 2017-02-28  137.08  137.435  136.70  136.99
# 2017-03-31  143.72  144.270  143.01  143.66
# 2017-04-30  144.09  144.300  143.27  143.65

# %%
df_volume2 = goog_table.loc['2018-01':'2018-06',['Volume', 'Split Ratio']].resample('M').agg(lambda x: x[-1])
print(df_volume2)
print('\n---------------------- separate line--------------------\n')
df_2018 = goog_table.loc['2018-01':'2018-06',['Open', 'High', 'Low', 'Close']].resample('M').agg(lambda x: x[-1])
print(df_2018)

# %%
concat = pd.concat([aapl_bar,df_volume],axis = 1)
print(concat)
# Out:
#               Open      High     Low   Close  rate_return      Volume  \
# Date
# 2016-01-31   94.79   97.3400   94.35   97.34          NaN         NaN
# 2016-02-29   96.86   98.2300   96.65   96.69    -0.006678         NaN
# 2016-03-31  109.72  109.9000  108.88  108.99     0.127211         NaN
# 2016-04-30   93.99   94.7200   92.51   93.74    -0.139921         NaN
# 2016-05-31   99.60  100.4000   98.82   99.86     0.065287         NaN
# 2016-06-30   94.44   95.7700   94.30   95.60    -0.042660         NaN
# 2016-07-31  104.19  104.5500  103.68  104.21     0.090063         NaN
# 2016-08-31  105.66  106.5699  105.64  106.10     0.018136         NaN
# 2016-09-30  112.46  113.3700  111.80  113.05     0.065504         NaN
# 2016-10-31  113.65  114.2300  113.20  113.54     0.004334  26419398.0
# 2016-11-30  111.56  112.2000  110.27  110.52    -0.026599  36162258.0
# 2016-12-31  116.65  117.2000  115.43  115.82     0.047955  30586265.0
# ...

# %%
concat2 = pd.concat([goog_bar,df_volume2],axis = 1)
print(concat2)

# %%
concat = pd.concat([aapl_bar,df_volume],axis = 1, join = 'inner')
print(concat)
# Out:
#               Open    High     Low   Close  rate_return      Volume  \
# Date
# 2016-10-31  113.65  114.23  113.20  113.54     0.004334  26419398.0
# 2016-11-30  111.56  112.20  110.27  110.52    -0.026599  36162258.0
# 2016-12-31  116.65  117.20  115.43  115.82     0.047955  30586265.0
#
#             Split Ratio
# Date
# 2016-10-31          1.0
# 2016-11-30          1.0
# 2016-12-31          1.0

# %%
concat2 = pd.concat([goog_bar,df_volume2],axis = 1, join = 'inner')
print(concat2)

# %%
append = aapl_bar.append(df_2017)
print(append)
# Out:
#              Close      High     Low    Open  rate_return
# Date
# 2016-01-31   97.34   97.3400   94.35   94.79          NaN
# 2016-02-29   96.69   98.2300   96.65   96.86    -0.006678
# 2016-03-31  108.99  109.9000  108.88  109.72     0.127211
# 2016-04-30   93.74   94.7200   92.51   93.99    -0.139921
# 2016-05-31   99.86  100.4000   98.82   99.60     0.065287
# 2016-06-30   95.60   95.7700   94.30   94.44    -0.042660
# 2016-07-31  104.21  104.5500  103.68  104.19     0.090063
# 2016-08-31  106.10  106.5699  105.64  105.66     0.018136
# 2016-09-30  113.05  113.3700  111.80  112.46     0.065504
# 2016-10-31  113.54  114.2300  113.20  113.65     0.004334
# 2016-11-30  110.52  112.2000  110.27  111.56    -0.026599
# 2016-12-31  115.82  117.2000  115.43  116.65     0.047955
# 2016-10-31  113.54  114.2300  113.20  113.65          NaN
# 2016-11-30  110.52  112.2000  110.27  111.56          NaN
# 2016-12-31  115.82  117.2000  115.43  116.65          NaN
# ...

# %%
append2 = goog_bar.append(df_2018)
print(append2)

# %%
concat = pd.concat([aapl_bar, df_2017], axis = 0)
print(concat)
# Out:
#              Close      High     Low    Open  rate_return
# Date
# 2016-01-31   97.34   97.3400   94.35   94.79          NaN
# 2016-02-29   96.69   98.2300   96.65   96.86    -0.006678
# 2016-03-31  108.99  109.9000  108.88  109.72     0.127211
# 2016-04-30   93.74   94.7200   92.51   93.99    -0.139921
# 2016-05-31   99.86  100.4000   98.82   99.60     0.065287
# 2016-06-30   95.60   95.7700   94.30   94.44    -0.042660
# 2016-07-31  104.21  104.5500  103.68  104.19     0.090063
# 2016-08-31  106.10  106.5699  105.64  105.66     0.018136
# 2016-09-30  113.05  113.3700  111.80  112.46     0.065504
# 2016-10-31  113.54  114.2300  113.20  113.65     0.004334
# 2016-11-30  110.52  112.2000  110.27  111.56    -0.026599
# 2016-12-31  115.82  117.2000  115.43  116.65     0.047955
# 2016-10-31  113.54  114.2300  113.20  113.65          NaN
# 2016-11-30  110.52  112.2000  110.27  111.56          NaN
# 2016-12-31  115.82  117.2000  115.43  116.65          NaN
# ...

# %%
concat2 = pd.concat2([goog_bar, df_2018], axis = 0)
print(concat2)

# %%
df_2017.columns = ['Change', 'High','Low','Close']
concat = pd.concat([aapl_bar, df_2017], axis = 0)
print(concat)
# Out:
#             Change   Close      High     Low    Open  rate_return
# Date
# 2016-01-31     NaN   97.34   97.3400   94.35   94.79          NaN
# 2016-02-29     NaN   96.69   98.2300   96.65   96.86    -0.006678
# 2016-03-31     NaN  108.99  109.9000  108.88  109.72     0.127211
# 2016-04-30     NaN   93.74   94.7200   92.51   93.99    -0.139921
# 2016-05-31     NaN   99.86  100.4000   98.82   99.60     0.065287
# 2016-06-30     NaN   95.60   95.7700   94.30   94.44    -0.042660
# 2016-07-31     NaN  104.21  104.5500  103.68  104.19     0.090063
# 2016-08-31     NaN  106.10  106.5699  105.64  105.66     0.018136
# 2016-09-30     NaN  113.05  113.3700  111.80  112.46     0.065504
# 2016-10-31     NaN  113.54  114.2300  113.20  113.65     0.004334
# 2016-11-30     NaN  110.52  112.2000  110.27  111.56    -0.026599
# 2016-12-31     NaN  115.82  117.2000  115.43  116.65     0.047955
# 2016-10-31  113.65  113.54  114.2300  113.20     NaN          NaN
# ...

# %%
df_2018.columns = ['Change', 'High','Low','Close']
concat2 = pd.concat2([goog_bar, df_2018], axis = 0)
print(concat2)

# %%
concat = pd.concat([aapl_bar, df_2017], axis = 0)
print(concat)
# Out:
#             Change   Close      High     Low    Open  rate_return
# Date
# 2016-01-31     NaN   97.34   97.3400   94.35   94.79          NaN
# 2016-02-29     NaN   96.69   98.2300   96.65   96.86    -0.006678
# 2016-03-31     NaN  108.99  109.9000  108.88  109.72     0.127211
# 2016-04-30     NaN   93.74   94.7200   92.51   93.99    -0.139921
# 2016-05-31     NaN   99.86  100.4000   98.82   99.60     0.065287
# 2016-06-30     NaN   95.60   95.7700   94.30   94.44    -0.042660
# 2016-07-31     NaN  104.21  104.5500  103.68  104.19     0.090063
# 2016-08-31     NaN  106.10  106.5699  105.64  105.66     0.018136
# 2016-09-30     NaN  113.05  113.3700  111.80  112.46     0.065504
# 2016-10-31     NaN  113.54  114.2300  113.20  113.65     0.004334
# 2016-11-30     NaN  110.52  112.2000  110.27  111.56    -0.026599
# 2016-12-31     NaN  115.82  117.2000  115.43  116.65     0.047955
# 2016-10-31  113.65  113.54  114.2300  113.20     NaN          NaN
# ...

# %%
concat2 = pd.concat2([goog_bar, df_2018], axis = 0)
print(concat2)
