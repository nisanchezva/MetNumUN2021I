# %% [markdown]
# 1.Python for Data Science : https://courses.cognitiveclass.ai/certificates/7eeaf6e4f34747f995f470cb772e0fd7
#
# 2.Data Analysis with Python : https://courses.cognitiveclass.ai/certificates/8c096a326cfc4d80a9cf5801bb2c45e4
#
# 3.Data Visualization with Python : https://courses.cognitiveclass.ai/certificates/4329b56a0c374b32902da79f1616eded
#
#
# linkedin :
#
# ![nisanchezvacognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)
